# %%
# !pip install scikit-learn matplotlib numpy --quiet

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# Generate 5000 random data points with 50 features
X = np.random.rand(5000, 50)

# %%
# Apply t-SNE with 2 components for 2D visualization
tsne = TSNE(n_components=2, random_state=42)
X_embedded = tsne.fit_transform(X)

# %%
# Plot the embedded data
plt.scatter(X_embedded[:, 0], X_embedded[:, 1])
plt.title("t-SNE visualization of 5000 sample data points")
plt.xlabel("t-SNE component 1")
plt.ylabel("t-SNE component 2")
plt.show()
