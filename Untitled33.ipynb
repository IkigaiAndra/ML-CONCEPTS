# %%
import numpy as np

# %%
data = np.random.rand(1000, 784)

# %%
from tensorflow import keras
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import numpy as np
from tensorflow import keras

# Load MNIST dataset
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()

# Preprocess the data
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Now you can use x_train and x_test to train and evaluate your autoencoder.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data points
num_points = 1000
data = np.random.rand(num_points, 2)  # 1000 points with 2 features each

# Plot the data
plt.scatter(data[:, 0], data[:, 1], s=10)  # s controls the size of the points
plt.title("Generated Data for Autoencoder")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
